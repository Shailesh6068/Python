# %%
import warnings

# %%
# Opening CSV file From an URL

import requests
import pandas as pd
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # TSV File read

# %%
# Option 1: Use raw string to avoid escape character issues
df = pd.read_csv(r"E:\ML\Dataset\titanic-parquet.tsv", sep='\t')

# Option 2: Escape backslashes
# df = pd.read_csv("E:\\ML\\Dataset\\titanic-parquet.tsv", sep='\t')

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    \N        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    \N        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    \N        S

# %%
df = pd.read_csv(r"E:\ML\Dataset\titanic-parquet.tsv", sep='\t',names=["PassengerId",'Survived'])
print(df.head())
# Out:
#                                                                                                                                PassengerId  \
# PassengerId Survived Pclass Name                                               Sex    Age SibSp Parch Ticket           Fare          Cabin
# 1           0        3      Braund, Mr. Owen Harris                            male   22  1     0     A/5 21171        7.25             \N
# 2           1        1      Cumings, Mrs. John Bradley (Florence Briggs Tha... female 38  1     0     PC 17599         71.2833         C85
# 3           1        3      Heikkinen, Miss. Laina                             female 26  0     0     STON/O2. 3101282 7.925            \N
# 4           1        1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 35  1     0     113803           53.1           C123
#
#                                                                                                                                 Survived
# ...

# %%
df = pd.read_csv(r"E:\ML\Dataset\titanic-parquet.tsv", sep='\t')
df = df.rename(columns={"PassengerId": "Id", "Pclass": "Passenger Class"})
df.head()
# Out:
#    Id  Survived  Passenger Class  \
# 0   1         0                3
# 1   2         1                1
# 2   3         1                3
# 3   4         1                1
# 4   5         0                3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    \N        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    \N        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    \N        S

# %%
# Make Column as a Index

df = pd.read_csv("E:\ML\Dataset\swiggy.csv",index_col="ID")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\1057759769.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",index_col="ID")
#             Area       City         Restaurant  Price  Avg ratings  \
# ID
# 211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#      Total ratings                                          Food type  \
# ID
# 211            100          Biryani,Chinese,North Indian,South Indian
# 221            100                                   Mughlai,Lucknowi
# ...

# %%
# In Some time our header are not correct beacuase of row number as 0. due this use header
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",header = 1 )
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\2587754524.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",header = 1 )
#    211  Koramangala  Bangalore        Tandoor Hut  300.0  4.4  100  \
# 0  221  Koramangala  Bangalore      Tunday Kababi  300.0  4.1  100
# 1  246    Jogupalya  Bangalore            Kim Lee  650.0  4.4  100
# 2  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0  3.9  500
# 3  249  Indiranagar  Bangalore                Nh8  350.0  4.0   50
# 4  254  Indiranagar  Bangalore              Treat  800.0  4.5  100
#
#            Biryani,Chinese,North Indian,South Indian      5Th Block  59
# 0                                   Mughlai,Lucknowi      5Th Block  56
# 1                                            Chinese    Double Road  50
# 2               North Indian,Punjabi,Tandoor,Chinese   80 Feet Road  57
# ...

# %%
# Use Specific Columns
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",usecols = ["ID","Area","City"])
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\1916140923.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",usecols = ["ID","Area","City"])
#     ID         Area       City
# 0  211  Koramangala  Bangalore
# 1  221  Koramangala  Bangalore
# 2  246    Jogupalya  Bangalore
# 3  248  Indiranagar  Bangalore
# 4  249  Indiranagar  Bangalore

# %%
# Skips row 1 and row 4 from the CSV file itself (not DataFrame index).
# These are 0-based row numbers:
# Row 0: ✅ Read as header (by default)
# Row 1: ❌ Skipped
# Row 2: ✅ Read

df = pd.read_csv("E:\ML\Dataset\swiggy.csv",skiprows=[1,4])
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\3047353068.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",skiprows=[1,4])
#     ID         Area       City                 Restaurant   Price  \
# 0  221  Koramangala  Bangalore              Tunday Kababi   300.0
# 1  246    Jogupalya  Bangalore                    Kim Lee   650.0
# 2  249  Indiranagar  Bangalore                        Nh8   350.0
# 3  254  Indiranagar  Bangalore                      Treat   800.0
# 4  258  Indiranagar  Bangalore  Chinita Real Mexican Food  1000.0
#
#    Avg ratings  Total ratings  \
# 0          4.1            100
# 1          4.4            100
# 2          4.0             50
# 3          4.5            100
# 4          4.5            500
#
#                                            Food type        Address  \
# ...

# %%
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",nrows = 100)
print(df.to_string())
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\25864922.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",nrows = 100)
# ...

# %%
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",encoding='utf-8',error_bad_lines = "False")
# Use Different Encoding for Different Csv file where encoding is not utf 8.
# error_bad_lines : Remove lines which are not converted correctly.
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\3712996261.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
# Convert Datatype 
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",dtype={"ID":float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   float64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 678.3+ KB
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\797576938.py:2: SyntaxWarning: invalid escape sequence '\M'
# ...

# %%
# This Convert your date Int type into DateTime Format.
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",date_parser=["Date"])

# %% [markdown]
# # Convertor

# %%
def rename(name):
    if name == "Indiranagar":
        return "Ind"
    else:
        return name

# %%
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",converters= {"Area":rename})
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\3514252141.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",converters= {"Area":rename})
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248          Ind  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249          Ind  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# ...

# %%
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",na_values=["Koramangala"])
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\3188548953.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",na_values=["Koramangala"])
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211          NaN  Bangalore        Tandoor Hut  300.0          4.4
# 1  221          NaN  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# ...

# %%
# Loading a huge Dataset
df = pd.read_csv("E:\ML\Dataset\swiggy.csv",chunksize=4000)

for chunk in df:
    print(chunk.shape)
# Out:
# (4000, 10)
# (4000, 10)
# (680, 10)
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Shailesh\AppData\Local\Temp\ipykernel_7604\821175000.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("E:\ML\Dataset\swiggy.csv",chunksize=4000)
